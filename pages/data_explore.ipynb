# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("cardio_train.csv",sep=';')

# %%
data
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %% [markdown]
# # Top Rows

# %%
data.head()

# %% [markdown]
# # Last Rows

# %%
data.tail()

# %% [markdown]
# # Total Columns

# %%
data.columns

# %% [markdown]
# # Shape of data

# %%
data.shape

# %% [markdown]
# # Describe the data

# %%
data.describe()

# %% [markdown]
# # datatype of each column

# %%
data.dtypes

# %% [markdown]
# # Total actives

# %%
data['active'].value_counts()

# %% [markdown]
# # Check null value

# %%
data.isnull().sum()

# %% [markdown]
# # check duplicated value

# %%
data.duplicated().sum()

# %% [markdown]
# # Cardio-wise age distribution

# %%
data.groupby('cardio')['age'].describe()

# %% [markdown]
# # Skewness of weight and BP

# %%
x=data['weight'].skew()
y= data['ap_hi'].skew()
x,y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x=data['weight'].skew()
#       2 y= data['ap_hi'].skew()
#       3 x,y
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Unique values

# %%
data.nunique()
# Out:
# id             70000
# age             8076
# gender             2
# height           109
# weight           287
# ap_hi            153
# ap_lo            157
# cholesterol        3
# gluc               3
# smoke              2
# alco               2
# active             2
# cardio             2
# dtype: int64

# %% [markdown]
# # Count of male and female

# %%
data.groupby('gender').size()
# Out:
# gender
# 1    45530
# 2    24470
# dtype: int64

# %% [markdown]
# # Age wise cholestrol mean

# %%
data.groupby('cholesterol')['age'].mean()
# Out:
# cholesterol
# 1    19283.308084
# 2    19604.875799
# 3    20512.962311
# Name: age, dtype: float64

# %% [markdown]
# # Feature correlation with cardio

# %%
data.corr()['cardio'].sort_values(ascending=False)
# Out:
# cardio         1.000000
# age            0.238159
# cholesterol    0.221147
# weight         0.181660
# gluc           0.089307
# ap_lo          0.065719
# ap_hi          0.054475
# gender         0.008109
# id             0.003799
# alco          -0.007330
# height        -0.010821
# smoke         -0.015486
# active        -0.035653
# Name: cardio, dtype: float64

# %%
corr=data.corr(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 corr=data.corr(numeric_only=True)
#
# NameError: name 'data' is not defined

# %% [markdown]
# # plot in the graph

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # Distribution of age

# %%
data['age_years'] = data['age'] / 365
sns.histplot(data['age_years'])
plt.title("Age Distribution")
plt.show()

# %% [markdown]
# # BMI Distribution

# %%
data['BMI'] = data['weight'] / (data['height']/100)**2
sns.histplot(data['BMI'])
plt.title("BMI Distribution")
# Out:
# Text(0.5, 1.0, 'BMI Distribution')

# %% [markdown]
# # Average lifestyle habit indicators

# %%
lifestyle_cols = ['smoke', 'alco', 'active']
data[lifestyle_cols].mean()
# Out:
# smoke     0.088129
# alco      0.053771
# active    0.803729
# dtype: float64

# %% [markdown]
# # Age distribution by cardio

# %%
sns.boxplot(x='cardio', y='age_years', data=data)
# Out:
# <Axes: xlabel='cardio', ylabel='age_years'>

# %% [markdown]
# # Cardio-wise mean health metrics

# %%
data.groupby('cardio')[['age', 'weight', 'ap_hi']].mean()
# Out:
#                  age     weight       ap_hi
# cardio
# 0       18881.623711  71.592150  120.432598
# 1       20056.813031  76.822368  137.212042
